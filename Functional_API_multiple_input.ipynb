# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushbokde/DL_study/blob/main/Functional_API_multiple_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import *
from keras.models import Model

# %%
inputA = Input(shape=(32, 32))
inputB = Input(shape=(128,))

# %%
x = Flatten()(inputA)
x = Dense(8, activation="relu")(x)
x1 = Dense(4, activation="relu")(x)

# %%
y = Dense(64, activation = "relu")(inputB)
y1 = Dense(32, activation = "relu")(y)
y2 = Dense(4,activation = "relu")(y1)
y2_flat = Flatten()(y2)

# %%
print(x1.shape)
print(y2.shape)
# Out:
# (None, 4)
# (None, 4)

# %%
combined = concatenate([x1, y2_flat])

# %%
z = Dense(2, activation="relu")(combined)
z1 = Dense(1, activation="linear")(z)

# %%
from keras.models import Model
model = Model(inputs=[inputA, inputB], outputs=z1)

# %%
from keras.utils import plot_model
plot_model(model)
